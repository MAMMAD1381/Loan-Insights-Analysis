# %% [markdown]
# # Imports

# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Load Loan Dataset

# %%
df = pd.read_csv('loan.csv')

# %%
df.head(5)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0          Age   Sex          Job Housing Saving accounts  \
# count   1000.000000  1000.000000  1000  1000.000000    1000             817
# unique          NaN          NaN     2          NaN       3               4
# top             NaN          NaN  male          NaN     own          little
# freq            NaN          NaN   690          NaN     713             603
# mean     499.500000    35.546000   NaN     1.904000     NaN             NaN
# std      288.819436    11.375469   NaN     0.653614     NaN             NaN
# min        0.000000    19.000000   NaN     0.000000     NaN             NaN
# 25%      249.750000    27.000000   NaN     2.000000     NaN             NaN
# 50%      499.500000    33.000000   NaN     2.000000     NaN             NaN
# 75%      749.250000    42.000000   NaN     2.000000     NaN             NaN
# max      999.000000    75.000000   NaN     3.000000     NaN             NaN
#
#        Checking account  Credit amount     Duration Purpose
# count               606    1000.000000  1000.000000    1000
# unique                3            NaN          NaN       8
# top              little            NaN          NaN     car
# freq                274            NaN          NaN     337
# mean                NaN    3271.258000    20.903000     NaN
# std                 NaN    2822.736876    12.058814     NaN
# min                 NaN     250.000000     4.000000     NaN
# 25%                 NaN    1365.500000    12.000000     NaN
# 50%                 NaN    2319.500000    18.000000     NaN
# 75%                 NaN    3972.250000    24.000000     NaN
# max                 NaN   18424.000000    72.000000     NaN

# %% [markdown]
# # Applying Onehat Encoding
# - Sex
# - Housing
# - Purpose

# %%
# Step 1: Apply one-hot encoding to categorical columns, without dropping any category
df_encoded = pd.get_dummies(df, columns=['Sex', 'Housing', 'Purpose'], drop_first=False)

# Step 2: Convert only the one-hot encoded columns (those that start with 'Sex_', 'Housing_', 'Purpose_') to int
one_hot_columns = [col for col in df_encoded.columns if 'Sex_' in col or 'Housing_' in col or 'Purpose_' in col]
df_encoded[one_hot_columns] = df_encoded[one_hot_columns].astype(int)

# %% [markdown]
# # Applying Mapping on Saving and Checking Accounts

# %%
mapping = {'little':0 ,'moderate':1,'quite rich':2, 'rich':3}
df_encoded['saving_map'] = df_encoded['Saving accounts'].map(mapping)
df_encoded['checking_map'] = df_encoded['Checking account'].map(mapping)

# %%
df_encoded
# Out:
#      Unnamed: 0  Age  Job Saving accounts Checking account  Credit amount  \
# 0             0   67    2             NaN           little           1169
# 1             1   22    2          little         moderate           5951
# 2             2   49    1          little              NaN           2096
# 3             3   45    2          little           little           7882
# 4             4   53    2          little           little           4870
# ..          ...  ...  ...             ...              ...            ...
# 995         995   31    1          little              NaN           1736
# 996         996   40    3          little           little           3857
# 997         997   38    2          little              NaN            804
# 998         998   23    2          little           little           1845
# 999         999   27    2        moderate         moderate           4576
#
#      Duration  Sex_female  Sex_male  Housing_free  ...  Purpose_business  \
# 0           6           0         1             0  ...                 0
# 1          48           1         0             0  ...                 0
# 2          12           0         1             0  ...                 0
# 3          42           0         1             1  ...                 0
# 4          24           0         1             1  ...                 0
# ..        ...         ...       ...           ...  ...               ...
# 995        12           1         0             0  ...                 0
# 996        30           0         1             0  ...                 0
# 997        12           0         1             0  ...                 0
# 998        45           0         1             1  ...                 0
# 999        45           0         1             0  ...                 0
#
#      Purpose_car  Purpose_domestic appliances  Purpose_education  \
# 0              0                            0                  0
# 1              0                            0                  0
# 2              0                            0                  1
# 3              0                            0                  0
# 4              1                            0                  0
# ..           ...                          ...                ...
# 995            0                            0                  0
# 996            1                            0                  0
# 997            0                            0                  0
# 998            0                            0                  0
# 999            1                            0                  0
#
#      Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                              0                 1                0
# 1                              0                 1                0
# 2                              0                 0                0
# 3                              1                 0                0
# 4                              0                 0                0
# ..                           ...               ...              ...
# 995                            1                 0                0
# 996                            0                 0                0
# 997                            0                 1                0
# 998                            0                 1                0
# 999                            0                 0                0
#
#      Purpose_vacation/others  saving_map  checking_map
# 0                          0         NaN           0.0
# 1                          0         0.0           1.0
# 2                          0         0.0           NaN
# 3                          0         0.0           0.0
# 4                          0         0.0           0.0
# ..                       ...         ...           ...
# 995                        0         0.0           NaN
# 996                        0         0.0           0.0
# 997                        0         0.0           NaN
# 998                        0         0.0           0.0
# 999                        0         1.0           1.0
#
# [1000 rows x 22 columns]

# %% [markdown]
# # Using Model To Fill Missing Values
# - Checking Account
# - Saving Account

# %%
df_saving = df_encoded.copy().drop(['Saving accounts','Checking account','checking_map'], axis=1)
df_checking = df_encoded.copy().drop(['Checking account','Saving accounts','saving_map'], axis=1)

# %%
df_saving_na =df_saving[df_saving.isna().any(axis=1)]
df_checking_na =df_checking[df_checking.isna().any(axis=1)]

# %%
df_saving_na
# Out:
#      Unnamed: 0  Age  Job  Credit amount  Duration  Sex_female  Sex_male  \
# 0             0   67    2           1169         6           0         1
# 5             5   35    1           9055        36           0         1
# 16           16   53    2           2424        24           0         1
# 17           17   25    2           8072        30           0         1
# 24           24   26    2           2069        10           0         1
# ..          ...  ...  ...            ...       ...         ...       ...
# 968         968   29    2           7166        42           0         1
# 977         977   42    2           2427        18           0         1
# 990         990   37    1           3565        12           0         1
# 992         992   23    1           1936        18           0         1
# 994         994   50    2           2390        12           0         1
#
#      Housing_free  Housing_own  Housing_rent  Purpose_business  Purpose_car  \
# 0               0            1             0                 0            0
# 5               1            0             0                 0            0
# 16              0            1             0                 0            0
# 17              0            1             0                 1            0
# 24              0            1             0                 0            0
# ..            ...          ...           ...               ...          ...
# 968             0            0             1                 0            0
# 977             0            1             0                 1            0
# 990             0            1             0                 0            0
# 992             0            0             1                 0            0
# 994             0            1             0                 0            1
#
#      Purpose_domestic appliances  Purpose_education  \
# 0                              0                  0
# 5                              0                  1
# 16                             0                  0
# 17                             0                  0
# 24                             0                  0
# ..                           ...                ...
# 968                            0                  0
# 977                            0                  0
# 990                            0                  1
# 992                            0                  0
# 994                            0                  0
#
#      Purpose_furniture/equipment  Purpose_radio/TV  Purpose_repairs  \
# 0                              0                 1                0
# 5                              0                 0                0
# 16                             0                 1                0
# 17                             0                 0                0
# 24                             1                 0                0
# ..                           ...               ...              ...
# 968                            0                 1                0
# 977                            0                 0                0
# 990                            0                 0                0
# 992                            0                 1                0
# 994                            0                 0                0
#
#      Purpose_vacation/others  saving_map
# 0                          0         NaN
# 5                          0         NaN
# 16                         0         NaN
# 17                         0         NaN
# 24                         0         NaN
# ..                       ...         ...
# 968                        0         NaN
# 977                        0         NaN
# 990                        0         NaN
# 992                        0         NaN
# 994                        0         NaN
#
# [183 rows x 19 columns]

# %%
X_saving_na = df_saving_na.drop(['Unnamed: 0','saving_map'],axis=1).values
X_checking_na = df_checking_na.drop(['Unnamed: 0','checking_map'],axis=1).values

# %%
df_saving_pre = df_saving.dropna()
df_checking_pre = df_checking.dropna()

# %%
X_saving = df_saving_pre.drop(['Unnamed: 0','saving_map'], axis=1).values
y_saving = df_saving_pre['saving_map'].values

# %%
X_checking = df_checking_pre.drop(['Unnamed: 0','checking_map'], axis=1).values
y_checking = df_checking_pre['checking_map'].values

# %% [markdown]
# ## Train and Predict on Saving Accounts

# %%
model = RandomForestClassifier()
model.fit(X_saving, y_saving)
y_pred_saving = model.predict(X_saving_na)

# %% [markdown]
# ## Train and Predict on Checking Accounts

# %%
model = RandomForestClassifier()
model.fit(X_checking, y_checking)
y_pred_checking = model.predict(X_checking_na)

# %%
# df_saving_na.loc[:, 'saving_map'] = y_pred_saving
# df_checking_na.loc[:, 'checking_map'] = y_pred_checking

# %% [markdown]
# # Applying Reverse Mapping
# - Checking Account
# - Saving Account

# %%
df_final = df.copy()

# %%
rows_saving = df_saving_na['Unnamed: 0'].values
rows_checking = df_checking_na['Unnamed: 0'].values

# %%
mapping = {'little': 0, 'moderate': 1, 'quite rich': 2, 'rich': 3}

reverse_mapping = {v: k for k, v in mapping.items()}

rows_to_fill = rows_saving
values_to_fill = y_pred_saving

for row, value in zip(rows_to_fill, values_to_fill):
    df_final.at[row, 'Saving accounts'] = reverse_mapping[value]

# %%
mapping = {'little': 0, 'moderate': 1, 'quite rich': 2, 'rich': 3}

reverse_mapping = {v: k for k, v in mapping.items()}

rows_to_fill = rows_checking
values_to_fill = y_pred_checking

for row, value in zip(rows_to_fill, values_to_fill):
    df_final.at[row, 'Checking account'] = reverse_mapping[value]

# %%
df_final.describe(include='all')
# Out:
#          Unnamed: 0          Age   Sex          Job Housing Saving accounts  \
# count   1000.000000  1000.000000  1000  1000.000000    1000            1000
# unique          NaN          NaN     2          NaN       3               4
# top             NaN          NaN  male          NaN     own          little
# freq            NaN          NaN   690          NaN     713             779
# mean     499.500000    35.546000   NaN     1.904000     NaN             NaN
# std      288.819436    11.375469   NaN     0.653614     NaN             NaN
# min        0.000000    19.000000   NaN     0.000000     NaN             NaN
# 25%      249.750000    27.000000   NaN     2.000000     NaN             NaN
# 50%      499.500000    33.000000   NaN     2.000000     NaN             NaN
# 75%      749.250000    42.000000   NaN     2.000000     NaN             NaN
# max      999.000000    75.000000   NaN     3.000000     NaN             NaN
#
#        Checking account  Credit amount     Duration Purpose
# count              1000    1000.000000  1000.000000    1000
# unique                3            NaN          NaN       8
# top              little            NaN          NaN     car
# freq                462            NaN          NaN     337
# mean                NaN    3271.258000    20.903000     NaN
# std                 NaN    2822.736876    12.058814     NaN
# min                 NaN     250.000000     4.000000     NaN
# 25%                 NaN    1365.500000    12.000000     NaN
# 50%                 NaN    2319.500000    18.000000     NaN
# 75%                 NaN    3972.250000    24.000000     NaN
# max                 NaN   18424.000000    72.000000     NaN

# %% [markdown]
# # Saving

# %%
df_final.to_csv('loan_cleaned.csv')
